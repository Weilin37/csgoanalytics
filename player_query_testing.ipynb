# %%
import numpy as np
import queries
import player_info

# %%
player1 = player_info.player(name='Mightymax')

# %%
player1
# Out:
# player(name='Mightymax', games_id=Empty DataFrame
# Columns: []
# Index: [], snapshots=Empty DataFrame
# Columns: []
# Index: [], ticks=Empty DataFrame
# Columns: []
# Index: [])

# %%
player1.populate_games_id()

# %%
player1.populate_snapshots()

# %%
player1.populate_ticks()

# %%
player1.name
# Out:
# 'Mightymax'

# %%
player1.games_id
# Out:
#   id  player_id player_name  team_id
# 0  1         12   Mightymax        3

# %%
player1.snapshots
# Out:
#      id    tick  player_id  position_x  position_y  position_z  angle   hp  \
# 0     1     256         12          45        2137        -127    194  100
# 1     1     512         12        -371        1945        -126    268  100
# 2     1     768         12        -320        1772        -115    264  100
# 3     1    1024         12        -438        1923        -126    269  100
# 4     1    1280         12        -457        2040         -83    270  100
# ...  ..     ...        ...         ...         ...         ...    ...  ...
# 1210  1  381952         12        -700         300           9     65   73
# 1211  1  382208         12        -632         445           8     64   73
# 1212  1  382464         12        -450         669           0     84   73
# 1213  1  382720         12        -160         940           0    112   73
# 1214  1  382976         12        -160         940           0    112   73
#
#       armor
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ...     ...
# 1210     91
# 1211     91
# 1212     91
# 1213     91
# 1214     91
#
# [1215 rows x 9 columns]

# %%
player1.ticks
# Out:
#     id    tick fire_entity jump_entity hurt_entity flashed_entity  \
# 0    1     345          12
# 1    1     546          12
# 2    1     704          12
# 3    1     865          12
# 4    1    1039          12
# ..  ..     ...         ...         ...         ...            ...
# 503  1  374283                      12
# 504  1  374862          12
# 505  1  375319          12
# 506  1  375759                                  12
# 507  1  382576                      12
#
#     footstep_entity swap_team_entity kill_killer kill_victim kill_weapon  \
# 0
# 1
# 2
# 3
# 4
# ..              ...              ...         ...         ...         ...
# 503
# 504
# 505
# 506
# 507
#
#     kill_assister round_started  current_round round_ended_winner  \
# 0                                            1
# 1                                            1
# 2                                            1
# 3                                            1
# 4                                            1
# ..            ...           ...            ...                ...
# 503                                         26
# 504                                         26
# 505                                         26
# 506                                         26
# 507                                         26
#
#     round_ended_reason
# 0
# 1
# 2
# 3
# 4
# ..                 ...
# 503
# 504
# 505
# 506
# 507
#
# [508 rows x 16 columns]

# %%
1 - np.mean(player1.ticks.loc[player1.ticks['fire_entity'] == '12', 'hurt_entity'] == '')
# Out:
# 0.13978494623655913

# %%
player1.shoot_accuracy()
# Out:
# array([0.13978495])
